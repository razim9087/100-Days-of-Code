# %% [markdown]
# <a href="https://colab.research.google.com/github/razim9087/100-Days-of-Code/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("Welcome to Rock-Paper-Scissors!!")
result=0
while result==0:
  your_turn=int(input("Enter 0 for rock, 1 for paper, 2 for scissor: "))
  if your_turn==0:
     print("You chose Rock!")
  elif your_turn==1:
     print("You chose Paper!")
  elif your_turn==2:
     print("You chose Scissor!")
  else:
     print("You chose an invald number. You Lose !")
     break
  computer_turn=random.randint(0,2)
  if computer_turn==0:
     print("Computer chose Rock!")
  elif computer_turn==1:
     print("Computer chose Paper!")
  else:
     print("Computer chose Scissor!")
  if your_turn==computer_turn:
    print("Play again !!")
  else:
    result=1
    if your_turn==0 and computer_turn==2:
      print("You Win!!")
    elif your_turn==1 and computer_turn==2:
      print("You Lose!!")
    elif your_turn==0 and computer_turn==1:
      print("You Lose!!")
    elif your_turn==2 and computer_turn==1:
      print("You Win!!")
    elif your_turn==1 and computer_turn==0:
      print("You Win!!")
    elif your_turn==2 and computer_turn==0:
      print("You Lose!!")
# Out:
# Welcome to Rock-Paper-Scissors!!
# Enter 0 for rock, 1 for paper, 2 for scissor: 2
# You chose Scissor!
# Computer chose Scissor!
# Play again !!
# Enter 0 for rock, 1 for paper, 2 for scissor: 1
# You chose Paper!
# Computer chose Rock!
# You Win!!
