# %% [markdown]
# <a href="https://colab.research.google.com/github/razim9087/100-Days-of-Code/blob/main/Day_3_Coding_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Python Pizza Deliveries")
size=input("What size of Pizza do you want? S, M or L: ")
pepperoni=input("Do you want pepperoni on your pizza? Y or N: ")
extra_cheese=input("Do you want extra cheese? Y or N: ")

price=0
if size=="S":
  price+=15
  if pepperoni=="Y":
    price+=2
elif size=="M":
  price+=20
  if pepperoni=="Y":
    price+=2
else:
  price+=25
  if pepperoni=="Y":
    price+=3
if extra_cheese=="Y":
  price+=1
print(f"Your Total Bill: {price}")
# Out:
# Welcome to Python Pizza Deliveries
# What size of Pizza do you want? S, M or L: M
# Do you want pepperoni on your pizza? Y or N: Y
# Do you want extra cheese? Y or N: Y
# Your Total Bill: 23
