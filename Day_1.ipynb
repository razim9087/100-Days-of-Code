# %% [markdown]
# <a href="https://colab.research.google.com/github/razim9087/100-Days-of-Code/blob/main/Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Band Name Generator")
name=input("Enter your birthplace: ")
pet=input("Enter the name of your pet: ")
print("Your band's name is "+name+" "+pet+".")
# Out:
# Welcome to Band Name Generator
# Enter your birthplace: Lisbon
# Enter the name of your pet: Legend
# Your band's name is Lisbon Legend.
