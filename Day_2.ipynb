# %% [markdown]
# <a href="https://colab.research.google.com/github/razim9087/100-Days-of-Code/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Wecome to the tip calculator")
total=int(input("Enter total bill value: "))
tip_percent=int(input("How much tip you would like to give?\nPlease enter the percentage as a number: "))
split=int(input("Enter the number of ways the bill will be split: "))
print(f"Each person should pay: {(total*(1+(tip_percent/100)))/split}")
# Out:
# Wecome to the tip calculator
# Enter total bill value: 100
# How much tip you would like to give?
# Please enter the percentage as a number: 20
# Enter the number of ways the bill will be split: 5
# Each person should pay: 24.0
